# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_groq import ChatGroq

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")


# def get_weather(city: str) -> str:
    # """get weather for a given city"""
    # return f"The weather in {city} is sunny with a high of 25°C."

llm = ChatGroq(model="openai/gpt-oss-120b",
               temperature=0.7, 
               max_tokens=2000)


agent = create_agent(
    model=llm,
    # tools=[get_weather],
    system_prompt="You are a helpful assistant"
)

result = agent.stream({
    "messages" : [
        {
            "role" : "user",
            "content" : "Explain Neural Networks"
        }
    ]
},
stream_mode="messages")

final_answer = ""
# Out:
# node: model
# content: []
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': 'The'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' user'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' asks'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' "'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': 'What'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' is'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' the'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' weather'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' in'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' SF'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '?"'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' The'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' system'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': " hasn't"}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' provided'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' any'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' external'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' data'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' The'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' user'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' wants'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' current'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' weather'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' As'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' Chat'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': 'GPT'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ','}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' we'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': " don't"}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' have'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' real'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '-time'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' data'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' We'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' should'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' respond'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' that'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' we'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': " don't"}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' have'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' live'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' data'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ','}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' suggest'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' checking'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' a'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' weather'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' website'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' or'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' app'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ','}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' or'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' provide'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' typical'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' climate'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' Also'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' note'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' SF'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' could'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' be'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' San'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' Francisco'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' Provide'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' typical'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' climate'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' info'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' Also'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' ask'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' if'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' they'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' need'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': ' forecast'}]
#
#
# node: model
# content: [{'type': 'reasoning', 'reasoning': '.'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'I'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’m'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' not'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' able'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' to'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' pull'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' live'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' data'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' so'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' I'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' can'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’t'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' give'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' you'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' current'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' conditions'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' in'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' San'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Franc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'isco'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' right'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' now'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '  \n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'For'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' most'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' up'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'to'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'date'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' forecast'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' you'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' can'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' check'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' any'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' of'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' these'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' reliable'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' sources'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ':\n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '-'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' **'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' websites'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ':**'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.com'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Acc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'u'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' National'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Service'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.gov'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '-'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' **'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Mobile'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' apps'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ':**'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' The'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Channel'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Acc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'u'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Underground'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' or'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' built'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'in'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' app'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' on'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' your'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' phone'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '-'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' **'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Voice'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' assistants'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ':**'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Ask'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Siri'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Google'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Assistant'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' or'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Alexa'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' for'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' “'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' in'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' San'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Franc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'isco'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '”\n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'If'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' you'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’d'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' like'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' a'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' quick'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' overview'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' of'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' what'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' San'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Franc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'isco'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’s'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' is'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' typically'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' like'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ':\n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Season'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Typical'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' High'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Typical'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Low'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Common'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Conditions'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '--------'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '--------------'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '------------'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '----------------'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '---'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Winter'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Dec'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Feb'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '55'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '60'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '13'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '16'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '45'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '50'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '7'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '10'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Cool'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' fog'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'gy'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' mornings'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ';'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' occasional'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' rain'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Spring'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Mar'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'May'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '60'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '65'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '16'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '18'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '48'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '53'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '9'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '12'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Fog'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' lifts'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' mild'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' sunshine'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Summer'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Jun'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Aug'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '65'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '70'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '18'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '21'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '53'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '57'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '12'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '14'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Often'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' cool'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' and'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' fog'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'gy'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' especially'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' near'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' coast'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ';'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' inland'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' areas'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' can'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' be'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' warmer'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '|'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Fall'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Sep'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Nov'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '65'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '70'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '18'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '21'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' '}]
#
#
# node: model
# content: [{'type': 'text', 'text': '53'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '58'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°F'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': '12'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '14'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '°C'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Warm'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' sunny'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' days'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' with'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' less'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' fog'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' especially'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' in'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' September'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' (“'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Indian'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Summer'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '”)'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' |\n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'San'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Franc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'isco'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’s'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' micro'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'cl'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'imates'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' mean'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' that'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' temperatures'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' can'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' vary'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' a'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' lot'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' block'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'by'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'block'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '—'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'dow'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'ntown'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' and'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' waterfront'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' are'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' usually'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' cooler'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' and'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' fog'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'g'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'ier'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' while'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' neighborhoods'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' a'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' few'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' miles'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' inland'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'like'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Mission'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' or'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' No'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'e'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Valley'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ')'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' can'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' feel'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' noticeably'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' warmer'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.\n\n'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'If'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' you'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' need'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' a'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' specific'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' forecast'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' ('}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'e'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.g'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.,'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' today'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’s'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' temperature'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' chance'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' of'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' rain'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ','}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' or'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' an'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' hour'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'by'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '‑'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'hour'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' outlook'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '),'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' just'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' let'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' me'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' know'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' which'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' service'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' you'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '’d'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' like'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' to'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' use'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' or'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' feel'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' free'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' to'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' check'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' one'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' of'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' links'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' above'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '!'}]
#
#
# node: model
# content: []
#
#
# node: model
# content: []
