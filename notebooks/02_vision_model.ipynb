# %%
import os
import getpass
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage


if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your GROQ API key: ")



llm = ChatGroq(
    model="qwen/qwen3.8-27b",
    max_tokens=1024,
)

message = HumanMessage(
    content=[
        {
            'type' : 'text', 'text' : 'Describe this image in detail'
        },{
            "type" : "image_url",
            "image_url" : {"url": "https://images.unsplash.com/photo-1503023345310-bd7c1de61c7d"}
        },

    ]
)

response = llm.invoke([message])
print(response.content)
# Out:
# This image is a composite of four distinct photographs, arranged in a 2x2 grid, all sharing a common theme of solitude and contemplation in vast, natural landscapes. The overall mood is serene, melancholic, and introspective, enhanced by a muted color palette dominated by earthy browns, grays, and soft blues.
#
# Here’s a detailed breakdown of each panel:
#
# **Top-Left Panel:**
# This is the most complete and iconic shot of the series. It features a person, seen from behind, standing in the middle of a wide, open field of tall, dry, golden-brown grasses that reach up to their waist. They are wearing a dark navy blue hooded jacket (with a visible "The North Face" logo on the upper back) and light-colored pants. Their posture is still and contemplative as they gaze out towards the horizon. In the distance, a range of mountains rises, partially veiled by low-hanging clouds or mist, creating a sense of depth and scale. The sky above is bright and overcast, casting a soft, diffused light over the entire scene. The composition centers the figure, emphasizing their smallness against the grandeur of nature.
#
# **Top-Right Panel:**
# This panel offers a closer, more intimate perspective. We see the back of the same person’s head and shoulders, positioned on the right side of the frame. Their short, light brown hair is visible. They are looking out at a breathtaking view of layered mountain ranges shrouded in thick, white fog or cloud cover. The mountains recede into the distance, becoming progressively lighter and less defined, creating a powerful sense of atmospheric perspective. The sky is almost entirely white, suggesting either heavy cloud cover or the brightness of the sun behind the clouds. This shot emphasizes the act of gazing and the overwhelming beauty of the landscape.
#
# **Bottom-Left Panel:**
# This image is a close-up, focusing on the texture and detail of the environment. It shows the lower half of the person’s body — specifically their leg in khaki or beige pants and the dark blue sleeve of their jacket — as they stand amidst the same tall, dry grasses. The grasses are rendered in sharp focus in the foreground, highlighting their individual stalks and seed heads, while the background is softly blurred. This perspective draws attention to the tactile quality of the natural world and the person’s physical presence within it.
#
# **Bottom-Right Panel:**
# The final panel is an extreme close-up, almost abstract, of the dry grasses. The image is dark and moody, with the grasses appearing as a dense, textured mass of brown and gold. A few tiny, out-of-focus purple specks, possibly wildflowers, are scattered throughout, adding a subtle touch of color. The shallow depth of field blurs the background completely, isolating the grasses and creating a sense of intimacy and quiet observation. This panel serves as a grounding element, bringing the viewer down to the level of the earth and the immediate surroundings.
#
# ---
#
# **Overall Impression:**
# Together, these four images create a cohesive narrative. They move from a wide, establishing shot to increasingly intimate details, inviting the viewer to share in the subject’s quiet moment of reflection. The consistent use of natural light, muted colors, and the recurring elements (the person, the grass, the mountains) tie the panels together into a single, evocative story about solitude, connection with nature, and the awe inspired by the natural world. The style is reminiscent of fine art photography or a cinematic still, capturing a fleeting, peaceful moment in a dramatic landscape.
