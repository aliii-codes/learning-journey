# %%
import os

from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate


load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")


prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms."
)


llm = ChatGroq(
    model="openai/gpt-oss-120b",
    max_tokens=2048,
    temperature=0.7,
)


prompt_value = prompt.invoke({
    "topic": "neural networks"
})


response = llm.invoke(prompt_value)


print(response.content)
# Out:
# ### Neural Networks in Plain English
#
# Imagine you’re trying to teach a kid how to recognize pictures of cats and dogs. You could show the kid lots of pictures, point out the differences (pointy ears, whiskers, tail shape, etc.), and over time the kid learns to tell them apart. A **neural network** works a lot like that kid—except it’s a computer program that learns from data instead of a human brain.
#
# Below is a step‑by‑step, low‑tech way to picture what’s going on.
#
# ---
#
# ## 1. The Building Block: “Artificial Neuron”
#
# - **What it is:** A tiny calculator that takes several numbers in, does a simple math operation, and spits out one number.
# - **How it works:**
#   1. **Inputs:** Think of them as clues (e.g., “the picture has a lot of gray pixels”).
#   2. **Weights:** Each clue gets a *importance* score (the weight). Bigger weight = more influence.
#   3. **Sum + Bias:** The neuron adds up (input × weight) for all clues, then adds a small constant called a *bias*.
#   4. **Activation:** It passes that sum through a simple rule (like “if the sum is > 0, say 1; otherwise say 0”) to decide its output.
#
# > **Analogy:** A neuron is like a tiny voting booth. Each clue casts a weighted vote, and the booth announces the result.
#
# ---
#
# ## 2. Putting Neurons Together: Layers
#
# - **Input layer:** The first row of neurons just passes the raw data (e.g., pixel values of an image) into the network.
# - **Hidden layers:** One or more rows of neurons that sit in the middle. They transform the raw clues into higher‑level concepts (edges → shapes → fur patterns → “cat‑ness”).
# - **Output layer:** The final row gives the answer (e.g., “cat” vs. “dog” probabilities).
#
# > **Analogy:** Think of a factory assembly line. Raw material (pixels) enters, each station (layer) adds a bit of processing, and at the end you get a finished product (the prediction).
#
# ---
#
# ## 3. Learning: Adjusting the Weights
#
# When the network first starts, its weights are random—so its guesses are basically guesswork. To improve:
#
# 1. **Show a labeled example:** Give it a picture of a cat *and* tell it “this is a cat.”
# 2. **Make a prediction:** The network runs the picture through its layers and outputs a guess (maybe “dog”).
# 3. **Measure the error:** Compare the guess to the true label. The difference is the *error*.
# 4. **Back‑propagation:** The network works backward, figuring out how each weight contributed to the error, and nudges the weights a tiny bit to reduce that error next time.
# 5. **Repeat:** Do this over thousands (or millions) of examples. The weights gradually settle into values that make the network good at the task.
#
# > **Analogy:** It’s like a student taking practice quizzes. After each quiz, they see which questions they got wrong, figure out why, and adjust their study notes accordingly.
#
# ---
#
# ## 4. Why “Neural”?
#
# - **Inspiration from biology:** Real brains have neurons that fire when they receive enough input. Artificial neurons mimic that idea in a very simplified way.
# - **But it’s not a brain:** The math is far simpler, and the “connections” (weights) are just numbers, not living tissue.
#
# ---
#
# ## 5. A Simple Real‑World Example
#
# **Task:** Predict whether an email is spam.
#
# | Feature (input) | Example value | Weight (learned) |
# |----------------|---------------|-----------------|
# | Contains the word “free”? | 1 (yes) | 0.8 |
# | Has an attachment? | 0 (no) | -0.2 |
# | Sender is in address book? | 0 (no) | -0.5 |
# | ... | ... | ... |
#
# The network adds up (feature × weight) + bias, runs it through an activation function, and outputs a probability like “0.92 = 92% likely spam.” If it’s wrong, back‑propagation adjusts those weights for the next email.
#
# ---
#
# ## 6. Key Takeaways
#
# | Concept | Simple Summary |
# |---------|----------------|
# | **Neuron** | Small math unit that adds weighted clues and decides a simple output. |
# | **Layer** | A row of neurons that together transform data into something more abstract. |
# | **Network** | Stacked layers that turn raw inputs into predictions. |
# | **Training** | Repeatedly showing examples, measuring mistakes, and tweaking weights. |
# | **Prediction** | Once trained, the network can guess on new, unseen data. |
#
# ---
#
# ## 7. Quick Visual Sketch
#
# ```
# [Pixel values] --> (Input layer) --> (Hidden layer 1) --> (Hidden layer 2) --> (Output layer) --> [Cat? Dog?]
# ```
#
# Each arrow represents the flow of numbers, and each layer is doing a little math to reshape those numbers.
#
# ---
#
# ### TL;DR
#
# A neural network is a computer program made of many tiny calculators (neurons) arranged in layers. It learns by adjusting the importance (weights) of each calculator based on lots of examples, eventually becoming good at tasks like recognizing images, translating languages, or spotting spam—all without being explicitly programmed for the specific rule. Think of it as a very fast, math‑based “learning machine” that mimics, in a crude way, how our brains combine signals to make decisions.
