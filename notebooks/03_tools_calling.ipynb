# %%
import os 
import getpass
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain.tools import tool

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your GROQ API key: ")

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    max_tokens=2048,
    temperature=0.7
)

@tool
def get_current_weather(location: str) -> str:
    """get the current weather of a given location"""
    # This is a placeholder implementation - replace with actual weather API call
    return f"The current weather in {location} is sunny."

agent = create_agent(
    model=llm,
    tools=[get_current_weather],
)

result =agent.invoke({
    "messages": [
        {
            "role" : "user",
            "content" : "What is the current weather in New York?"
        }
    ]
})

print(result["messages"][-1].content)
# Out:
# The current weather in New York is sunny. Enjoy the clear skies!
