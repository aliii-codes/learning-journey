# %%
import os 
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain.tools import tool
from github import Github, Auth


load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GITHUB_TOKEN"] = os.getenv("GITHUB_TOKEN")

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    max_tokens=2048,
    temperature=0.7
)

def get_github_clients() -> Github:
    token = os.getenv("GITHUB_TOKEN")

    if not token:
        raise ValueError("GITHUB_TOKEN is not set in the environment variables.")

    return Github(auth=Auth.Token(token))

@tool
def get_github_repo(repo_name: str) -> str:
    """Get basic information about a GitHub repository."""

    github = get_github_clients()
    repo = github.get_repo(repo_name)

    return (
        f"Repository: {repo.full_name}\n"
        f"Description: {repo.description}\n"
        f"Stars: {repo.stargazers_count}\n"
        f"Forks: {repo.forks_count}\n"
        f"Language: {repo.language}\n"
        f"URL: {repo.html_url}"
    )


agent = create_agent(
    model=llm,
    tools=[get_github_repo],
    # agent_type="zero-shot-react-description"
)

result = agent.invoke({
    "messages" : [
        {
            "role" : "user",
            "content" : "tell me about aliii-codes/Moodline"
        }
    ]
})
    
print(result["messages"][-1].content)
# Out:
# **Repository Overview – `aliii-codes/Moodline`**
#
# | Item | Details |
# |------|---------|
# | **GitHub URL** | <https://github.com/aliii-codes/Moodline> |
# | **Primary Language** | Jupyter Notebook (`.ipynb`) |
# | **Stars** | 0 |
# | **Forks** | 0 |
# | **Description** | *None provided in the repository metadata* |
#
# ### What the repo appears to be about
# - **Name clue:** *Moodline* suggests a project focused on tracking, visualizing, or analyzing mood‑related data (e.g., a personal mood journal, sentiment analysis, or a simple “mood line” chart).
# - **File type:** The sole language listed is Jupyter Notebook, indicating the core of the project is an interactive notebook rather than a packaged library or application. This typically means the author is experimenting with data, visualizations, or machine‑learning models in a step‑by‑step, explanatory format.
#
# ### Typical contents you might expect in a notebook‑centric mood‑tracking repo
# 1. **Data import & preprocessing** – loading CSV/JSON logs of mood entries (date, time, rating, notes, etc.).
# 2. **Exploratory Data Analysis (EDA)** – histograms of mood scores, heatmaps of mood over weeks/months, correlation with external factors (sleep, exercise, weather).
# 3. **Visualization** – line plots (the “mood line”), rolling averages, interactive plots with `plotly` or `ipywidgets`.
# 4. **Statistical / ML modeling** – simple time‑series forecasting, clustering of mood patterns, or sentiment analysis of free‑text notes using `nltk`/`spaCy`.
# 5. **Export / reporting** – generating PDF/HTML reports or saving processed data for later use.
#
# ### How to get the most out of this repository
# 1. **Open the notebook** on GitHub (or clone the repo and launch it locally with Jupyter). Look for a README or top‑cell markdown that explains the purpose, data sources, and usage instructions.
# 2. **Check for data files** – the notebook may reference a `data/` folder or external CSV/JSON files. If they’re not included, the author might expect you to supply your own mood log.
# 3. **Run the cells step‑by‑step** – because notebooks often depend on the order of execution, start from the first cell and watch for any required Python packages (`pandas`, `numpy`, `matplotlib`, `seaborn`, `plotly`, etc.). Install missing packages via `pip` or `conda`.
# 4. **Explore the visualizations** – interactive widgets (sliders, dropdowns) can let you filter by date range, mood categories, or other variables.
# 5. **Contribute** – if you find the project useful, consider adding a short README, licensing info, or example data so others can quickly understand and reuse it. A star or fork can also help the author gauge interest.
#
# ### Quick next steps for you
# - **Visit the repo**: <https://github.com/aliii-codes/Moodline>
# - **Read any existing markdown cells** in the notebook for context.
# - **Clone & run** (if you have Jupyter installed):
#   ```bash
#   git clone https://github.com/aliii-codes/Moodline.git
#   cd Moodline
#   jupyter notebook
#   ```
# - **If you want to contribute**: add a `README.md` describing the project’s goal, required data format, and how to reproduce the analyses.
#
# Since the repository currently has no description, stars, or forks, it’s likely a personal or early‑stage experiment. Adding documentation and sample data would make it far more discoverable and useful to the community.
